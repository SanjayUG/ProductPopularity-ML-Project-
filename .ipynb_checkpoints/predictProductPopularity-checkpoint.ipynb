# %%
# loading necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

import warnings
warnings.filterwarnings('ignore')

train = pd.read_csv(r"C:\Users\Ram-R\Desktop\ProductPopularity(ML)\Train.csv")

# %%
# The first 5 observation 
train.head()
# Out:
#    Store_Ratio  Basket_Ratio  Category_1  Store_Score  Category_2  \
# 0        0.407       0.00380           2      -35.865           1
# 1        0.234       0.10500           0      -19.884           1
# 2        0.668       0.72600           9       -7.512           1
# 3        0.184       0.00561           4      -34.357           1
# 4        0.231       0.13100           6      -22.842           1
#
#    Store_Presence  Score_1  Score_2  Score_3  Score_4    time  popularity
# 0          0.9920    0.944   0.0988   0.1100  113.911  189125           4
# 1          0.9440    0.900   0.1290   0.0382   76.332  186513           4
# 2          0.0387    0.000   0.1340   0.4530  124.075  172143           4
# 3          0.8490    0.931   0.1110   0.0641   79.037  184000           5
# 4          0.9370    0.000   0.1090   0.0677  109.560  186507           3

# %%
# The last 5 observation 
train.tail()
# Out:
#        Store_Ratio  Basket_Ratio  Category_1  Store_Score  Category_2  \
# 18203        0.403       0.28100           6      -10.365           0
# 18204        0.481       0.01140           4      -26.196           1
# 18205        0.168       0.00908           5      -33.966           0
# 18206        0.598       0.65800           1       -7.159           0
# 18207        0.582       0.32400           2      -10.284           1
#
#        Store_Presence   Score_1  Score_2  Score_3  Score_4    time  popularity
# 18203           0.454  0.000000   0.1060    0.182  112.881  232880           4
# 18204           0.991  0.967000   0.0985    0.343   57.748  155500           4
# 18205           0.947  0.946000   0.1250    0.396   68.775  172500           4
# 18206           0.389  0.000000   0.5820    0.473  106.807  152558           4
# 18207           0.807  0.000034   0.1500    0.249   88.755  237293           3

# %%
# The size of the data set 
train.shape
# Out:
# (18208, 12)

# %%
# Feature information
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18208 entries, 0 to 18207
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Store_Ratio     18208 non-null  float64
#  1   Basket_Ratio    18208 non-null  float64
#  2   Category_1      18208 non-null  int64
#  3   Store_Score     18208 non-null  float64
#  4   Category_2      18208 non-null  int64
#  5   Store_Presence  18208 non-null  float64
#  6   Score_1         18208 non-null  float64
#  7   Score_2         18208 non-null  float64
#  8   Score_3         18208 non-null  float64
#  9   Score_4         18208 non-null  float64
#  10  time            18208 non-null  int64
#  11  popularity      18208 non-null  int64
# dtypes: float64(8), int64(4)
# memory usage: 1.7 MB

# %%
# checking duplicate values in DataFrame
duplicates = train.duplicated()
print(duplicates.sum())     # Number of duplicated rows
print(train[duplicates])    # Duplicated rows
# Out:
# 2923
#        Store_Ratio  Basket_Ratio  Category_1  Store_Score  Category_2  \
# 455          0.641       0.32400          11       -5.851           1
# 591          0.112       0.02640           7      -28.927           1
# 598          0.687       0.57700          10       -7.801           0
# 629          0.320       0.00892           8      -29.206           1
# 661          0.704       0.88400           8       -6.275           1
# ...            ...           ...         ...          ...         ...
# 18195        0.730       0.70500           5       -4.358           0
# 18196        0.147       0.38100           1      -28.083           1
# 18197        0.532       0.02020           4      -22.763           1
# 18204        0.481       0.01140           4      -26.196           1
# 18205        0.168       0.00908           5      -33.966           0
#
#        Store_Presence   Score_1  Score_2  Score_3  Score_4    time  popularity
# 455           0.69800  0.000000   0.3280   0.2730  110.184  185487           4
# 591           0.82100  0.806000   0.1130   0.0596   68.141  277555           4
# 598           0.11800  0.841000   0.1080   0.6060   91.988  122609           4
# 629           0.99600  0.919000   0.1100   0.3380   91.366  165904           4
# 661           0.54900  0.000364   0.0492   0.9640   93.058  228554           4
# ...               ...       ...      ...      ...      ...     ...         ...
# 18195         0.28600  0.000000   0.1130   0.6550  139.924  175000           4
# 18196         0.00136  0.951000   0.0947   0.1430   97.966  210450           4
# 18197         0.99300  0.935000   0.1060   0.2850   85.445  168611           4
# 18204         0.99100  0.967000   0.0985   0.3430   57.748  155500           4
# 18205         0.94700  0.946000   0.1250   0.3960   68.775  172500           4
#
# [2923 rows x 12 columns]

# %%
# To remove duplicates in-place:
train.drop_duplicates(inplace=True)

# %%
# checking duplicate values in DataFrame
duplicates = train.duplicated()
print(duplicates.sum())     # Number of duplicated rows
print(train[duplicates])    # Duplicated rows
# Out:
# 0
# Empty DataFrame
# Columns: [Store_Ratio, Basket_Ratio, Category_1, Store_Score, Category_2, Store_Presence, Score_1, Score_2, Score_3, Score_4, time, popularity]
# Index: []

# %%
train.isnull().sum()
# Out:
# Store_Ratio       0
# Basket_Ratio      0
# Category_1        0
# Store_Score       0
# Category_2        0
# Store_Presence    0
# Score_1           0
# Score_2           0
# Score_3           0
# Score_4           0
# time              0
# popularity        0
# dtype: int64

# %%
# The size of the data set 
train.shape
# Out:
# (15285, 12)

# %%
# getting type of columns
column_types = train.dtypes
print(column_types)
# Out:
# Store_Ratio       float64
# Basket_Ratio      float64
# Category_1          int64
# Store_Score       float64
# Category_2          int64
# Store_Presence    float64
# Score_1           float64
# Score_2           float64
# Score_3           float64
# Score_4           float64
# time                int64
# popularity          int64
# dtype: object

# %%
#getting correlation between target variable and other variables
corr= train.corr()
corr.style.background_gradient(cmap='BrBG')
# Out:
# <style type="text/css">
# #T_592ff_row0_col0, #T_592ff_row1_col1, #T_592ff_row2_col2, #T_592ff_row3_col3, #T_592ff_row4_col4, #T_592ff_row5_col5, #T_592ff_row6_col6, #T_592ff_row7_col7, #T_592ff_row8_col8, #T_592ff_row9_col9, #T_592ff_row10_col10, #T_592ff_row11_col11 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col1 {
#   background-color: #81cec2;
#   color: #000000;
# }
# #T_592ff_row0_col2, #T_592ff_row2_col7, #T_592ff_row2_col11, #T_592ff_row3_col2, #T_592ff_row9_col7 {
#   background-color: #ad7021;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col3 {
#   background-color: #58b0a7;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col4 {
#   background-color: #6c3e07;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col5, #T_592ff_row9_col11 {
#   background-color: #bf812d;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col6, #T_592ff_row7_col11, #T_592ff_row8_col2 {
#   background-color: #ab6e1f;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col7, #T_592ff_row10_col4 {
#   background-color: #93580f;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col8, #T_592ff_row8_col0, #T_592ff_row8_col1 {
#   background-color: #64b9ae;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col9, #T_592ff_row3_col7 {
#   background-color: #d4ac62;
#   color: #000000;
# }
# #T_592ff_row0_col10, #T_592ff_row1_col5, #T_592ff_row2_col4, #T_592ff_row3_col6, #T_592ff_row4_col2, #T_592ff_row5_col0, #T_592ff_row5_col1, #T_592ff_row5_col3, #T_592ff_row5_col7, #T_592ff_row5_col9, #T_592ff_row5_col11, #T_592ff_row6_col3, #T_592ff_row6_col8, #T_592ff_row6_col10 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_592ff_row0_col11 {
#   background-color: #ecd8a5;
#   color: #000000;
# }
# #T_592ff_row1_col0 {
#   background-color: #b6e3dd;
#   color: #000000;
# }
# #T_592ff_row1_col2 {
#   background-color: #af7222;
#   color: #f1f1f1;
# }
# #T_592ff_row1_col3 {
#   background-color: #02675f;
#   color: #f1f1f1;
# }
# #T_592ff_row1_col4, #T_592ff_row5_col8, #T_592ff_row6_col11 {
#   background-color: #663a07;
#   color: #f1f1f1;
# }
# #T_592ff_row1_col6 {
#   background-color: #7c4709;
#   color: #f1f1f1;
# }
# #T_592ff_row1_col7, #T_592ff_row10_col6 {
#   background-color: #efdcad;
#   color: #000000;
# }
# #T_592ff_row1_col8 {
#   background-color: #95d6cc;
#   color: #000000;
# }
# #T_592ff_row1_col9, #T_592ff_row4_col1 {
#   background-color: #f3e4bb;
#   color: #000000;
# }
# #T_592ff_row1_col10, #T_592ff_row7_col2 {
#   background-color: #a16518;
#   color: #f1f1f1;
# }
# #T_592ff_row1_col11 {
#   background-color: #e7cf94;
#   color: #000000;
# }
# #T_592ff_row2_col0, #T_592ff_row2_col8 {
#   background-color: #e8d29a;
#   color: #000000;
# }
# #T_592ff_row2_col1 {
#   background-color: #f5f2e8;
#   color: #000000;
# }
# #T_592ff_row2_col3 {
#   background-color: #f6edd7;
#   color: #000000;
# }
# #T_592ff_row2_col5 {
#   background-color: #f6ebcf;
#   color: #000000;
# }
# #T_592ff_row2_col6, #T_592ff_row3_col9 {
#   background-color: #f4e5be;
#   color: #000000;
# }
# #T_592ff_row2_col9, #T_592ff_row8_col7 {
#   background-color: #b57826;
#   color: #f1f1f1;
# }
# #T_592ff_row2_col10 {
#   background-color: #774508;
#   color: #f1f1f1;
# }
# #T_592ff_row3_col0 {
#   background-color: #79c8bc;
#   color: #000000;
# }
# #T_592ff_row3_col1 {
#   background-color: #01655d;
#   color: #f1f1f1;
# }
# #T_592ff_row3_col4, #T_592ff_row3_col5, #T_592ff_row4_col10 {
#   background-color: #734208;
#   color: #f1f1f1;
# }
# #T_592ff_row3_col8 {
#   background-color: #9ad8ce;
#   color: #000000;
# }
# #T_592ff_row3_col10 {
#   background-color: #955910;
#   color: #f1f1f1;
# }
# #T_592ff_row3_col11, #T_592ff_row7_col8, #T_592ff_row11_col5 {
#   background-color: #e8d097;
#   color: #000000;
# }
# #T_592ff_row4_col0 {
#   background-color: #cd9d50;
#   color: #f1f1f1;
# }
# #T_592ff_row4_col3 {
#   background-color: #eedbaa;
#   color: #000000;
# }
# #T_592ff_row4_col5 {
#   background-color: #f4f5f5;
#   color: #000000;
# }
# #T_592ff_row4_col6, #T_592ff_row10_col5 {
#   background-color: #f6ebcd;
#   color: #000000;
# }
# #T_592ff_row4_col7, #T_592ff_row10_col2 {
#   background-color: #975b12;
#   color: #f1f1f1;
# }
# #T_592ff_row4_col8 {
#   background-color: #dbb972;
#   color: #000000;
# }
# #T_592ff_row4_col9, #T_592ff_row10_col7, #T_592ff_row11_col7 {
#   background-color: #a5691b;
#   color: #f1f1f1;
# }
# #T_592ff_row4_col11 {
#   background-color: #9d6116;
#   color: #f1f1f1;
# }
# #T_592ff_row5_col2, #T_592ff_row11_col10 {
#   background-color: #844c09;
#   color: #f1f1f1;
# }
# #T_592ff_row5_col4 {
#   background-color: #c38936;
#   color: #f1f1f1;
# }
# #T_592ff_row5_col6 {
#   background-color: #6abdb2;
#   color: #000000;
# }
# #T_592ff_row5_col10 {
#   background-color: #613806;
#   color: #f1f1f1;
# }
# #T_592ff_row6_col0 {
#   background-color: #5b3406;
#   color: #f1f1f1;
# }
# #T_592ff_row6_col1 {
#   background-color: #995d13;
#   color: #f1f1f1;
# }
# #T_592ff_row6_col2, #T_592ff_row7_col4, #T_592ff_row9_col4, #T_592ff_row11_col4 {
#   background-color: #8b500a;
#   color: #f1f1f1;
# }
# #T_592ff_row6_col4 {
#   background-color: #9f6317;
#   color: #f1f1f1;
# }
# #T_592ff_row6_col5 {
#   background-color: #5eb5aa;
#   color: #f1f1f1;
# }
# #T_592ff_row6_col7, #T_592ff_row7_col10, #T_592ff_row8_col10 {
#   background-color: #794608;
#   color: #f1f1f1;
# }
# #T_592ff_row6_col9 {
#   background-color: #5d3506;
#   color: #f1f1f1;
# }
# #T_592ff_row7_col0 {
#   background-color: #d9b76f;
#   color: #000000;
# }
# #T_592ff_row7_col1 {
#   background-color: #cbebe6;
#   color: #000000;
# }
# #T_592ff_row7_col3 {
#   background-color: #f5f4f2;
#   color: #000000;
# }
# #T_592ff_row7_col5 {
#   background-color: #ead59f;
#   color: #000000;
# }
# #T_592ff_row7_col6 {
#   background-color: #ebd6a2;
#   color: #000000;
# }
# #T_592ff_row7_col9 {
#   background-color: #bb7d2a;
#   color: #f1f1f1;
# }
# #T_592ff_row8_col3 {
#   background-color: #76c6ba;
#   color: #000000;
# }
# #T_592ff_row8_col4 {
#   background-color: #894f0a;
#   color: #f1f1f1;
# }
# #T_592ff_row8_col5 {
#   background-color: #c58e3d;
#   color: #f1f1f1;
# }
# #T_592ff_row8_col6 {
#   background-color: #a3671a;
#   color: #f1f1f1;
# }
# #T_592ff_row8_col9 {
#   background-color: #e4ca8c;
#   color: #000000;
# }
# #T_592ff_row8_col11, #T_592ff_row10_col8 {
#   background-color: #e1c684;
#   color: #000000;
# }
# #T_592ff_row9_col0 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_592ff_row9_col1 {
#   background-color: #ccebe7;
#   color: #000000;
# }
# #T_592ff_row9_col2, #T_592ff_row11_col2 {
#   background-color: #9b5f14;
#   color: #f1f1f1;
# }
# #T_592ff_row9_col3 {
#   background-color: #d5edea;
#   color: #000000;
# }
# #T_592ff_row9_col5 {
#   background-color: #e5cc8f;
#   color: #000000;
# }
# #T_592ff_row9_col6 {
#   background-color: #dec17b;
#   color: #000000;
# }
# #T_592ff_row9_col8, #T_592ff_row11_col8 {
#   background-color: #f6edd5;
#   color: #000000;
# }
# #T_592ff_row9_col10 {
#   background-color: #874e0a;
#   color: #f1f1f1;
# }
# #T_592ff_row10_col0 {
#   background-color: #d2a75c;
#   color: #000000;
# }
# #T_592ff_row10_col1 {
#   background-color: #f5f4f0;
#   color: #000000;
# }
# #T_592ff_row10_col3 {
#   background-color: #f6eed9;
#   color: #000000;
# }
# #T_592ff_row10_col9 {
#   background-color: #bd7f2c;
#   color: #f1f1f1;
# }
# #T_592ff_row10_col11 {
#   background-color: #b37625;
#   color: #f1f1f1;
# }
# #T_592ff_row11_col0 {
#   background-color: #f5f1e6;
#   color: #000000;
# }
# #T_592ff_row11_col1 {
#   background-color: #d9eeeb;
#   color: #000000;
# }
# #T_592ff_row11_col3 {
#   background-color: #e4f1ef;
#   color: #000000;
# }
# #T_592ff_row11_col6 {
#   background-color: #e3c989;
#   color: #000000;
# }
# #T_592ff_row11_col9 {
#   background-color: #c48b3a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_592ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_592ff_level0_col0" class="col_heading level0 col0" >Store_Ratio</th>
#       <th id="T_592ff_level0_col1" class="col_heading level0 col1" >Basket_Ratio</th>
#       <th id="T_592ff_level0_col2" class="col_heading level0 col2" >Category_1</th>
#       <th id="T_592ff_level0_col3" class="col_heading level0 col3" >Store_Score</th>
#       <th id="T_592ff_level0_col4" class="col_heading level0 col4" >Category_2</th>
#       <th id="T_592ff_level0_col5" class="col_heading level0 col5" >Store_Presence</th>
#       <th id="T_592ff_level0_col6" class="col_heading level0 col6" >Score_1</th>
#       <th id="T_592ff_level0_col7" class="col_heading level0 col7" >Score_2</th>
#       <th id="T_592ff_level0_col8" class="col_heading level0 col8" >Score_3</th>

# %%
#plotting displot for depicting frequency of value of target variables
plt.figure(figsize=(10,6))
sns.distplot(train['popularity'])
plt.show()

# %%
#plotting histogram for variables for easy understanding
for i in train.columns:
    plt.figure(figsize=(6,4))
    sns.histplot(train[i])

# %%
# Defining X and y variable for training and testing
X = train.drop("popularity",axis=1)   # dropping target variable or taking all other variables except target variable
y = train["popularity"]               # taking target variable 
# Train-Test Separation
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=12345)

# %%
# Decision tree 
from sklearn.tree import DecisionTreeClassifier
# Initialize the decision tree classifier
dt = DecisionTreeClassifier()
# Train the model
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Make predictions
y_pred_dt = dt.predict(X_test)

# %%
# Evaluate the model
accuracy_dt = accuracy_score(y_test, y_pred_dt)
print("Accuracy:", accuracy_dt)
print("Classification Report:")
print(classification_report(y_test, y_pred_dt))
# Out:
# Accuracy: 0.7595682041216879
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.02      0.02      0.02        62
#            3       0.24      0.25      0.25       356
#            4       0.87      0.87      0.87      2557
#            5       0.08      0.08      0.08        78
#
#     accuracy                           0.76      3057
#    macro avg       0.44      0.44      0.44      3057
# weighted avg       0.76      0.76      0.76      3057

# %%
# Random Forest 
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=46)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=46)

# %%
# Make predictions
y_pred_rf = rf.predict(X_test)

# %%
# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print("Accuracy:", accuracy_rf)
print("Classification Report:")
print(classification_report(y_test, y_pred_rf))
# Out:
# Accuracy: 0.8387307818122343
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.00      0.00      0.00        62
#            3       0.43      0.09      0.15       356
#            4       0.85      0.99      0.91      2557
#            5       0.00      0.00      0.00        78
#
#     accuracy                           0.84      3057
#    macro avg       0.46      0.42      0.41      3057
# weighted avg       0.76      0.84      0.78      3057

# %%
# Support Vector Machine (SVM)
from sklearn import svm
# Create an SVM classifier with an RBF kernel
sv = svm.SVC(kernel='rbf')
sv.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Make predictions
y_pred_sv = sv.predict(X_test)

# %%
# Evaluate the model
accuracy_svm = accuracy_score(y_test, y_pred_sv)
print("Accuracy:", accuracy_svm)
print("Classification Report:")
print(classification_report(y_test, y_pred_sv))
# Out:
# Accuracy: 0.8364409551848218
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.00      0.00      0.00        62
#            3       0.00      0.00      0.00       356
#            4       0.84      1.00      0.91      2557
#            5       0.00      0.00      0.00        78
#
#     accuracy                           0.84      3057
#    macro avg       0.17      0.20      0.18      3057
# weighted avg       0.70      0.84      0.76      3057

# %%
# K Nearest Neighbour(KNN)
from sklearn.neighbors import KNeighborsClassifier 
k= 10
knn = KNeighborsClassifier(n_neighbors=k)
# Train the model
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
# Make predictions
y_pred_knn = knn.predict(X_test)

# %%
# Evaluate the model
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print("Accuracy:", accuracy_knn)
print("Classification Report:")
print(classification_report(y_test, y_pred_knn))
# Out:
# Accuracy: 0.8318613019299967
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.00      0.00      0.00        62
#            3       0.21      0.02      0.03       356
#            4       0.84      0.99      0.91      2557
#            5       0.00      0.00      0.00        78
#
#     accuracy                           0.83      3057
#    macro avg       0.21      0.20      0.19      3057
# weighted avg       0.73      0.83      0.76      3057

# %%
#CrossValidation of a Model
from sklearn.model_selection import cross_val_score, cross_validate

def evaluate_model_with_cv(model, X, y, cv=5):
    scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
    print(f"Model: {model.__class__.__name__}")
    print(f"Mean Accuracy: {scores.mean():.4f}")
    print(f"Standard Deviation: {scores.std():.4f}")
    print("-" * 30)

# Initialize models
models = [
    DecisionTreeClassifier(),
    RandomForestClassifier(random_state=46),
    svm.SVC(kernel='rbf'),
    KNeighborsClassifier(n_neighbors=10)
]

# Evaluate each model with cross-validation
for model in models:
    evaluate_model_with_cv(model, X, y, cv=5)
# Out:
# Model: DecisionTreeClassifier
# Mean Accuracy: 0.7558
# Standard Deviation: 0.0099
# ------------------------------
# Model: RandomForestClassifier
# Mean Accuracy: 0.8398
# Standard Deviation: 0.0010
# ------------------------------
# Model: SVC
# Mean Accuracy: 0.8407
# Standard Deviation: 0.0000
# ------------------------------
# Model: KNeighborsClassifier
# Mean Accuracy: 0.8374
# Standard Deviation: 0.0011
# ------------------------------
